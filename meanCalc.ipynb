# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def calcMean(file):
    df = pd.read_csv(file)
    c = 0
    for sent in range(len(df)):
        c += (df.iloc[sent][0]*df.iloc[sent][1])
    return c/df['sentiCR'].sum()

# %%
def calcFreq(file):
    df = pd.read_csv(file)
    temp = {}
    for _, row in df.iterrows():
        temp.update({row[0]: row[1]})
    return temp

# %%
go_fileList = ['golang_Nov2019-Jan2020-CR.csv', 'golang_Feb2020-Apr2020-CR.csv', 'golang_May2020-Jul2020-CR.csv', 'golang_Aug2020-Sep2020-CR.csv']
go_lst = [calcMean(file) for file in go_fileList]
go_df = pd.DataFrame({'Nov2019-Jan2020': go_lst[0], 'Feb2020-Apr2020': go_lst[1], 'May2020-Jul2020': go_lst[2], 'Aug2020-Sep2020': go_lst[3]}, index=[0])
go_df.T.plot.bar(yticks= np.linspace(0, -0.5, 11)[:4], xlabel='Month of the Year', ylabel='Average Sentiment Score', figsize=(12,6)).legend(loc='upper right', title='(Negative:-1 - Neutral:0 - Positive:1)', labels=[-1])
plt.title('GoLang: Nov 2019 - Sep 2020 Average Sentiment Distribution', fontsize= 14, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'GoLang: Nov 2019 - Sep 2020 Average Sentiment Distribution')

# %%
clojure_fileList = ['clojure_Nov2019-Jan2020-CR.csv', 'clojure_Feb2020-Apr2020-CR.csv', 'clojure_May2020-Jul2020-CR.csv', 'clojure_Aug2020-Oct2020-CR.csv']
clojure_lst = [calcMean(file) for file in clojure_fileList]
clojure_df = pd.DataFrame({'Nov2019-Jan2020': clojure_lst[0], 'Feb2020-Apr2020': clojure_lst[1], 'May2020-Jul2020': clojure_lst[2], 'Aug2020-Oct2020': clojure_lst[3]}, index=[0])
clojure_df.T.plot.bar(yticks= np.linspace(0, -0.5, 11)[:4], xlabel='Month of the Year', ylabel='Average Sentiment Score', figsize=(12,6)).legend(loc='upper right', title='(Negative:-1 - Neutral:0 - Positive:1)', labels=[-1])
plt.title('Clojurians: Nov 2019 - Oct 2020 Average Sentiment Distribution', fontsize= 14, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Clojurians: Nov 2019 - Oct 2020 Average Sentiment Distribution')

# %%
racket_fileList = ['racketgeneral_Nov2019-Jan2020-CR.csv', 'acket_general_Feb2020-Apr2020-CR.csv', 'acket_general_May2020-Jul2020-CR.csv', 'acket_general_Aug2020-Oct2020-CR.csv']
racket_lst = [calcMean(file) for file in racket_fileList]
racket_df = pd.DataFrame({'Nov2019-Jan2020': racket_lst[0], 'Feb2020-Apr2020': racket_lst[1], 'May2020-Jul2020': racket_lst[2], 'Aug2020-Oct2020': racket_lst[3]}, index=[0])
racket_df.T.plot.bar(yticks= np.linspace(0, -0.5, 11)[:4], xlabel='Month of the Year', ylabel='Average Sentiment Score', figsize=(12,6)).legend(loc='upper right', title='(Negative:-1 - Neutral:0 - Positive:1)', labels=[-1])
plt.title('Racket: Nov 2019 - Oct 2020 Average Sentiment Distribution', fontsize= 14, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Racket: Nov 2019 - Oct 2020 Average Sentiment Distribution')

# %%
python_fileList = ['pythongeneralNov2019-CR.csv', 'pythongeneralDec2019-CR.csv', 'pythongeneralJan2020-CR.csv', 'pythongeneralFeb2020-CR.csv',
                   'pythongeneralMar2020-CR.csv', 'pythongeneralApr2020-CR.csv', 'pythongeneralMay2020-CR.csv', 'pythongeneralJun2020-CR.csv',
                   'pythongeneralJul2020-CR.csv', 'pythongeneralAug2020-CR.csv', 'pythongeneralSep2020-CR.csv', 'pythongeneralOct2020-CR.csv']
python_lst = [calcMean(file) for file in python_fileList]
python_df = pd.DataFrame({'Nov2019': python_lst[0], 'Dec2019': python_lst[1], 'Jan2020': python_lst[2], 'Feb2020': python_lst[3],
                          'Mar2020': python_lst[4], 'Apr2020': python_lst[5], 'May2020': python_lst[6], 'Jun2020': python_lst[7],
                          'Jul2020': python_lst[8], 'Aug2020': python_lst[9], 'Sep2020': python_lst[10], 'Oct2020': python_lst[11]}, index=[0])
python_df.T.plot.bar(yticks= np.linspace(0, -0.5, 11)[:4], xlabel='Month of the Year', ylabel='Average Sentiment Score', figsize=(12,6)).legend(loc='upper right', title='(Negative:-1 - Neutral:0 - Positive:1)', labels=[-1])
plt.title('Python: Nov 2019 - Oct 2020 Average Sentiment Distribution', fontsize= 14, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Python: Nov 2019 - Oct 2020 Average Sentiment Distribution')

# %%
go_freq = [calcFreq(file) for file in go_fileList]
go_df_freq = pd.DataFrame(go_freq, index=go_df.columns)
go_df_freq[[-1,1]].plot.bar(yticks= range(0,16000, 2000), xlabel='Time Interval -Month of the Year', ylabel='Sentiment Frequency', figsize=(12,6)).legend(loc='upper right', title='(Negative:-1 - Neutral:0 - Positive:1)')
plt.title('GoLang: Nov 2019 - Sep 2020 Monthly Sentiment Frequency Distribution', fontsize= 14, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'GoLang: Nov 2019 - Sep 2020 Monthly Sentiment Frequency Distribution')

# %%
clojure_freq = [calcFreq(file) for file in clojure_fileList]
clojure_df_freq = pd.DataFrame(clojure_freq, index=clojure_df.columns)
clojure_df_freq[[-1,1]].plot.bar(xlabel='Time Interval -Month of the Year', ylabel='Sentiment Frequency', figsize=(12,6)).legend(loc='upper right', title='(Negative:-1 - Neutral:0 - Positive:1)')
plt.title('Clojurians: Nov 2019 - Oct 2020 Monthly Sentiment Frequency Distribution', fontsize= 14, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Clojurians: Nov 2019 - Oct 2020 Monthly Sentiment Frequency Distribution')

# %%
racket_freq = [calcFreq(file) for file in racket_fileList]
racket_df_freq = pd.DataFrame(racket_freq, index=racket_df.columns)
racket_df_freq[[-1,1]].plot.bar(xlabel='Time Interval -Month of the Year', ylabel='Sentiment Frequency', figsize=(12,6)).legend(loc='upper right', title='(Negative:-1 - Neutral:0 - Positive:1)')
plt.title('Racket: Nov 2019 - Oct 2020 Monthly Sentiment Frequency Distribution', fontsize= 14, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Racket: Nov 2019 - Oct 2020 Monthly Sentiment Frequency Distribution')

# %%
python_freq = [calcFreq(file) for file in python_fileList]
python_df_freq = pd.DataFrame(python_freq, index=python_df.columns)
python_df_freq[[-1,1]].plot.bar(xlabel='Time Interval -Month of the Year', ylabel='Sentiment Frequency', figsize=(12,6)).legend(loc='upper right', title='(Negative:-1 - Neutral:0 - Positive:1)')
plt.title('Python: Nov 2019 - Oct 2020 Monthly Sentiment Frequency Distribution', fontsize= 14, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Python: Nov 2019 - Oct 2020 Monthly Sentiment Frequency Distribution')

# %%
joint_freq = [go_df_freq[0],clojure_df_freq[0], racket_df_freq[0]]
joint_freq = pd.DataFrame(joint_freq)
joint_freq
# Out:
#    Nov2019-Jan2020  Feb2020-Apr2020  May2020-Jul2020  Aug2020-Sep2020  \
# 0          31074.0          56520.0          59338.0          47318.0
# 0            266.0            334.0            268.0              NaN
# 0            830.0            882.0            589.0              NaN
#
#    Aug2020-Oct2020
# 0              NaN
# 0            264.0
# 0           1446.0
